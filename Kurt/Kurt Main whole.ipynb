# %% [markdown]
# ## Library Imports

# %%
# Cell 1
import numpy as np
import pandas as pd
import glob
import os
import logging
import tensorflow as tf
from tqdm import tqdm
from datetime import datetime
from scipy.stats import skew, kurtosis
from tensorflow.keras import layers, Model
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LSTM, Dense

# %% [markdown]
# # Pre-processing of files

# %%
# Cell 2
def load_emothaw_data(directory_path):
    """
    Modified to aggregate features per file instead of per row
    """
    all_file_data = []  # Will store one entry per file instead of per row
    all_file_labels = []  # Will store one label per file

    file_paths = glob.glob(os.path.join(directory_path, "*.svc"))
    if not file_paths:
        raise ValueError("No files found in the specified directory")

    for file_path in file_paths:
        print(f"Processing file: {file_path}")
        try:
            # Extract the label from the filename
            label = int(os.path.basename(file_path).split('_')[0])

            with open(file_path, 'r') as f:
                lines = [line.strip() for line in f.readlines() if line.strip()]

            df = pd.DataFrame([line.split() for line in lines])

            if df.empty:
                print(f"Warning: {file_path} is empty after processing. Skipping file.")
                continue

            total_rows = int(df.iloc[0, 0])
            data = df.iloc[1:, :].values

            # Validate and reshape data
            reshaped_data = []
            for row in data:
                if len(row) == 7:
                    reshaped_data.append(row)

            if reshaped_data:
                reshaped_data = np.array(reshaped_data, dtype=float)
                
                # Store entire file's data as one entry
                all_file_data.append(reshaped_data)
                all_file_labels.append(label)

                print(f"Processed file {file_path}: Shape {reshaped_data.shape}")

        except Exception as e:
            print(f"Error processing file {file_path}: {e}")
            continue

    if not all_file_data or not all_file_labels:
        raise ValueError("No valid data found in the directory")

    return all_file_data, np.array(all_file_labels)

# Importing all files on the Directory
data, labels = load_emothaw_data(r'../test/withsynthethic/')  # Directory path
# Out:
# Processing file: ../test/withsynthethic\0_hw00001 (2).svc
# Processed file ../test/withsynthethic\0_hw00001 (2).svc: Shape (1702, 7)
# Processing file: ../test/withsynthethic\0_hw00001.svc
# Processed file ../test/withsynthethic\0_hw00001.svc: Shape (2643, 7)
# Processing file: ../test/withsynthethic\0_hw00002 (2).svc
# Processed file ../test/withsynthethic\0_hw00002 (2).svc: Shape (3398, 7)
# Processing file: ../test/withsynthethic\0_hw00002.svc
# Processed file ../test/withsynthethic\0_hw00002.svc: Shape (5691, 7)
# Processing file: ../test/withsynthethic\0_hw00003 (2).svc
# Processed file ../test/withsynthethic\0_hw00003 (2).svc: Shape (3373, 7)
# Processing file: ../test/withsynthethic\0_hw00003.svc
# Processed file ../test/withsynthethic\0_hw00003.svc: Shape (3863, 7)
# Processing file: ../test/withsynthethic\0_hw00004 (2).svc
# Processed file ../test/withsynthethic\0_hw00004 (2).svc: Shape (819, 7)
# Processing file: ../test/withsynthethic\0_hw00004.svc
# Processed file ../test/withsynthethic\0_hw00004.svc: Shape (1178, 7)
# Processing file: ../test/withsynthethic\0_hw00005 (2).svc
# Processed file ../test/withsynthethic\0_hw00005 (2).svc: Shape (724, 7)
# Processing file: ../test/withsynthethic\0_hw00005.svc
# Processed file ../test/withsynthethic\0_hw00005.svc: Shape (770, 7)
# Processing file: ../test/withsynthethic\0_hw00006 (2).svc
# Processed file ../test/withsynthethic\0_hw00006 (2).svc: Shape (3325, 7)
# Processing file: ../test/withsynthethic\0_hw00006.svc
# Processed file ../test/withsynthethic\0_hw00006.svc: Shape (4051, 7)
# Processing file: ../test/withsynthethic\0_hw00007 (2).svc
# Processed file ../test/withsynthethic\0_hw00007 (2).svc: Shape (3318, 7)
# Processing file: ../test/withsynthethic\0_hw00007.svc
# Processed file ../test/withsynthethic\0_hw00007.svc: Shape (3050, 7)
# Processing file: ../test/withsynthethic\0_synthetichw00001 (2).svc
# Processed file ../test/withsynthethic\0_synthetichw00001 (2).svc: Shape (1715, 7)
# Processing file: ../test/withsynthethic\0_synthetichw00001.svc
# Processed file ../test/withsynthethic\0_synthetichw00001.svc: Shape (2908, 7)
# Processing file: ../test/withsynthethic\0_synthetichw00002 (2).svc
# Processed file ../test/withsynthethic\0_synthetichw00002 (2).svc: Shape (3594, 7)
# Processing file: ../test/withsynthethic\0_synthetichw00002.svc
# Processed file ../test/withsynthethic\0_synthetichw00002.svc: Shape (6133, 7)
# Processing file: ../test/withsynthethic\0_synthetichw00003 (2).svc
# Processed file ../test/withsynthethic\0_synthetichw00003 (2).svc: Shape (3444, 7)
# Processing file: ../test/withsynthethic\0_synthetichw00004 (2).svc
# Processed file ../test/withsynthethic\0_synthetichw00004 (2).svc: Shape (818, 7)
# Processing file: ../test/withsynthethic\0_synthetichw00004.svc
# Processed file ../test/withsynthethic\0_synthetichw00004.svc: Shape (1177, 7)
# Processing file: ../test/withsynthethic\0_synthetichw00005 (2).svc
# Processed file ../test/withsynthethic\0_synthetichw00005 (2).svc: Shape (723, 7)
# Processing file: ../test/withsynthethic\0_synthetichw00005.svc
# Processed file ../test/withsynthethic\0_synthetichw00005.svc: Shape (769, 7)
# Processing file: ../test/withsynthethic\0_synthetichw00006 (2).svc
# Processed file ../test/withsynthethic\0_synthetichw00006 (2).svc: Shape (3352, 7)
# Processing file: ../test/withsynthethic\0_synthetichw00006.svc
# Processed file ../test/withsynthethic\0_synthetichw00006.svc: Shape (4257, 7)
# Processing file: ../test/withsynthethic\0_synthetichw00007 (2).svc
# Processed file ../test/withsynthethic\0_synthetichw00007 (2).svc: Shape (3360, 7)
# Processing file: ../test/withsynthethic\0_synthetichw00007.svc
# Processed file ../test/withsynthethic\0_synthetichw00007.svc: Shape (3079, 7)
# Processing file: ../test/withsynthethic\0_sythetichw00003.svc
# Processed file ../test/withsynthethic\0_sythetichw00003.svc: Shape (4086, 7)
# Processing file: ../test/withsynthethic\1_hw00001 (2).svc
# Processed file ../test/withsynthethic\1_hw00001 (2).svc: Shape (1648, 7)
# Processing file: ../test/withsynthethic\1_hw00001.svc
# Processed file ../test/withsynthethic\1_hw00001.svc: Shape (2560, 7)
# Processing file: ../test/withsynthethic\1_hw00002 (2).svc
# Processed file ../test/withsynthethic\1_hw00002 (2).svc: Shape (4433, 7)
# Processing file: ../test/withsynthethic\1_hw00002.svc
# Processed file ../test/withsynthethic\1_hw00002.svc: Shape (3098, 7)
# Processing file: ../test/withsynthethic\1_hw00003 (2).svc
# Processed file ../test/withsynthethic\1_hw00003 (2).svc: Shape (3636, 7)
# Processing file: ../test/withsynthethic\1_hw00003.svc
# Processed file ../test/withsynthethic\1_hw00003.svc: Shape (3268, 7)
# Processing file: ../test/withsynthethic\1_hw00004 (2).svc
# Processed file ../test/withsynthethic\1_hw00004 (2).svc: Shape (931, 7)
# Processing file: ../test/withsynthethic\1_hw00004.svc
# Processed file ../test/withsynthethic\1_hw00004.svc: Shape (1452, 7)
# Processing file: ../test/withsynthethic\1_hw00005 (2).svc
# Processed file ../test/withsynthethic\1_hw00005 (2).svc: Shape (716, 7)
# Processing file: ../test/withsynthethic\1_hw00005.svc
# Processed file ../test/withsynthethic\1_hw00005.svc: Shape (786, 7)
# Processing file: ../test/withsynthethic\1_hw00006 (2).svc
# Processed file ../test/withsynthethic\1_hw00006 (2).svc: Shape (4220, 7)
# Processing file: ../test/withsynthethic\1_hw00006.svc
# Processed file ../test/withsynthethic\1_hw00006.svc: Shape (1605, 7)
# Processing file: ../test/withsynthethic\1_hw00007 (2).svc
# Processed file ../test/withsynthethic\1_hw00007 (2).svc: Shape (3251, 7)
# Processing file: ../test/withsynthethic\1_hw00007.svc
# Processed file ../test/withsynthethic\1_hw00007.svc: Shape (2615, 7)
# Processing file: ../test/withsynthethic\1_synthetichw00001 (2).svc
# Processed file ../test/withsynthethic\1_synthetichw00001 (2).svc: Shape (1661, 7)
# Processing file: ../test/withsynthethic\1_synthetichw00001.svc
# Processed file ../test/withsynthethic\1_synthetichw00001.svc: Shape (2611, 7)
# Processing file: ../test/withsynthethic\1_synthetichw00002 (2).svc
# Processed file ../test/withsynthethic\1_synthetichw00002 (2).svc: Shape (4676, 7)
# Processing file: ../test/withsynthethic\1_synthetichw00003 (2).svc
# Processed file ../test/withsynthethic\1_synthetichw00003 (2).svc: Shape (3933, 7)
# Processing file: ../test/withsynthethic\1_synthetichw00003.svc
# Processed file ../test/withsynthethic\1_synthetichw00003.svc: Shape (3398, 7)
# Processing file: ../test/withsynthethic\1_synthetichw00004 (2).svc
# Processed file ../test/withsynthethic\1_synthetichw00004 (2).svc: Shape (931, 7)
# Processing file: ../test/withsynthethic\1_synthetichw00004.svc
# Processed file ../test/withsynthethic\1_synthetichw00004.svc: Shape (1479, 7)
# Processing file: ../test/withsynthethic\1_synthetichw00005 (2).svc
# Processed file ../test/withsynthethic\1_synthetichw00005 (2).svc: Shape (715, 7)
# Processing file: ../test/withsynthethic\1_synthetichw00005.svc
# Processed file ../test/withsynthethic\1_synthetichw00005.svc: Shape (785, 7)
# Processing file: ../test/withsynthethic\1_synthetichw00006 (2).svc
# Processed file ../test/withsynthethic\1_synthetichw00006 (2).svc: Shape (4752, 7)
# Processing file: ../test/withsynthethic\1_synthetichw00006.svc
# Processed file ../test/withsynthethic\1_synthetichw00006.svc: Shape (1614, 7)
# Processing file: ../test/withsynthethic\1_synthetichw00007 (2).svc
# Processed file ../test/withsynthethic\1_synthetichw00007 (2).svc: Shape (3559, 7)
# Processing file: ../test/withsynthethic\1_synthetichw00007.svc
# Processed file ../test/withsynthethic\1_synthetichw00007.svc: Shape (2665, 7)
# Processing file: ../test/withsynthethic\2_hw00001 (2).svc
# Processed file ../test/withsynthethic\2_hw00001 (2).svc: Shape (2085, 7)
# Processing file: ../test/withsynthethic\2_hw00001.svc
# Processed file ../test/withsynthethic\2_hw00001.svc: Shape (1474, 7)
# Processing file: ../test/withsynthethic\2_hw00002 (2).svc
# Processed file ../test/withsynthethic\2_hw00002 (2).svc: Shape (3800, 7)
# Processing file: ../test/withsynthethic\2_hw00002.svc
# Processed file ../test/withsynthethic\2_hw00002.svc: Shape (2735, 7)
# Processing file: ../test/withsynthethic\2_hw00003 (2).svc
# Processed file ../test/withsynthethic\2_hw00003 (2).svc: Shape (4276, 7)
# Processing file: ../test/withsynthethic\2_hw00003.svc
# Processed file ../test/withsynthethic\2_hw00003.svc: Shape (3102, 7)
# Processing file: ../test/withsynthethic\2_hw00004 (2).svc
# Processed file ../test/withsynthethic\2_hw00004 (2).svc: Shape (1111, 7)
# Processing file: ../test/withsynthethic\2_hw00004.svc
# Processed file ../test/withsynthethic\2_hw00004.svc: Shape (1951, 7)
# Processing file: ../test/withsynthethic\2_hw00005 (2).svc
# Processed file ../test/withsynthethic\2_hw00005 (2).svc: Shape (862, 7)
# Processing file: ../test/withsynthethic\2_hw00005.svc
# Processed file ../test/withsynthethic\2_hw00005.svc: Shape (1208, 7)
# Processing file: ../test/withsynthethic\2_hw00006 (2).svc
# Processed file ../test/withsynthethic\2_hw00006 (2).svc: Shape (3178, 7)
# Processing file: ../test/withsynthethic\2_hw00006.svc
# Processed file ../test/withsynthethic\2_hw00006.svc: Shape (2507, 7)
# Processing file: ../test/withsynthethic\2_hw00007 (2).svc
# Processed file ../test/withsynthethic\2_hw00007 (2).svc: Shape (3154, 7)
# Processing file: ../test/withsynthethic\2_hw00007.svc
# Processed file ../test/withsynthethic\2_hw00007.svc: Shape (2985, 7)
# Processing file: ../test/withsynthethic\2_synthetichw00001 (2).svc
# Processed file ../test/withsynthethic\2_synthetichw00001 (2).svc: Shape (2103, 7)
# Processing file: ../test/withsynthethic\2_synthetichw00001.svc
# Processed file ../test/withsynthethic\2_synthetichw00001.svc: Shape (1539, 7)
# Processing file: ../test/withsynthethic\2_synthetichw00002 (2).svc
# Processed file ../test/withsynthethic\2_synthetichw00002 (2).svc: Shape (3977, 7)
# Processing file: ../test/withsynthethic\2_synthetichw00002.svc
# Processed file ../test/withsynthethic\2_synthetichw00002.svc: Shape (2755, 7)
# Processing file: ../test/withsynthethic\2_synthetichw00003 (2).svc
# Processed file ../test/withsynthethic\2_synthetichw00003 (2).svc: Shape (4368, 7)
# Processing file: ../test/withsynthethic\2_synthetichw00003.svc
# Processed file ../test/withsynthethic\2_synthetichw00003.svc: Shape (3144, 7)
# Processing file: ../test/withsynthethic\2_synthetichw00004 (2).svc
# Processed file ../test/withsynthethic\2_synthetichw00004 (2).svc: Shape (1110, 7)
# Processing file: ../test/withsynthethic\2_synthetichw00004.svc
# Processed file ../test/withsynthethic\2_synthetichw00004.svc: Shape (2378, 7)
# Processing file: ../test/withsynthethic\2_synthetichw00005 (2).svc
# Processed file ../test/withsynthethic\2_synthetichw00005 (2).svc: Shape (861, 7)
# Processing file: ../test/withsynthethic\2_synthetichw00005.svc
# Processed file ../test/withsynthethic\2_synthetichw00005.svc: Shape (1207, 7)
# Processing file: ../test/withsynthethic\2_synthetichw00006 (2).svc
# Processed file ../test/withsynthethic\2_synthetichw00006 (2).svc: Shape (3288, 7)
# Processing file: ../test/withsynthethic\2_synthetichw00006.svc
# Processed file ../test/withsynthethic\2_synthetichw00006.svc: Shape (2736, 7)
# Processing file: ../test/withsynthethic\2_synthetichw00007 (2).svc
# Processed file ../test/withsynthethic\2_synthetichw00007 (2).svc: Shape (3201, 7)
# Processing file: ../test/withsynthethic\3_hw00001 (2).svc
# Processed file ../test/withsynthethic\3_hw00001 (2).svc: Shape (2801, 7)
# Processing file: ../test/withsynthethic\3_hw00001.svc
# Processed file ../test/withsynthethic\3_hw00001.svc: Shape (2983, 7)
# Processing file: ../test/withsynthethic\3_hw00002 (2).svc
# Processed file ../test/withsynthethic\3_hw00002 (2).svc: Shape (4417, 7)
# Processing file: ../test/withsynthethic\3_hw00002.svc
# Processed file ../test/withsynthethic\3_hw00002.svc: Shape (5639, 7)
# Processing file: ../test/withsynthethic\3_hw00003 (2).svc
# Processed file ../test/withsynthethic\3_hw00003 (2).svc: Shape (3568, 7)
# Processing file: ../test/withsynthethic\3_hw00003.svc
# Processed file ../test/withsynthethic\3_hw00003.svc: Shape (3857, 7)
# Processing file: ../test/withsynthethic\3_hw00004 (2).svc
# Processed file ../test/withsynthethic\3_hw00004 (2).svc: Shape (667, 7)
# Processing file: ../test/withsynthethic\3_hw00004.svc
# Processed file ../test/withsynthethic\3_hw00004.svc: Shape (1272, 7)
# Processing file: ../test/withsynthethic\3_hw00005 (2).svc
# Processed file ../test/withsynthethic\3_hw00005 (2).svc: Shape (513, 7)
# Processing file: ../test/withsynthethic\3_hw00005.svc
# Processed file ../test/withsynthethic\3_hw00005.svc: Shape (990, 7)
# Processing file: ../test/withsynthethic\3_hw00006 (2).svc
# Processed file ../test/withsynthethic\3_hw00006 (2).svc: Shape (3598, 7)
# Processing file: ../test/withsynthethic\3_hw00006.svc
# Processed file ../test/withsynthethic\3_hw00006.svc: Shape (6790, 7)
# Processing file: ../test/withsynthethic\3_hw00007 (2).svc
# Processed file ../test/withsynthethic\3_hw00007 (2).svc: Shape (3474, 7)
# Processing file: ../test/withsynthethic\3_hw00007.svc
# Processed file ../test/withsynthethic\3_hw00007.svc: Shape (3661, 7)
# Processing file: ../test/withsynthethic\synthetic1_hw00002.svc
# Error processing file ../test/withsynthethic\synthetic1_hw00002.svc: invalid literal for int() with base 10: 'synthetic1'
# Processing file: ../test/withsynthethic\synthetic_2_hw00007.svc
# Error processing file ../test/withsynthethic\synthetic_2_hw00007.svc: invalid literal for int() with base 10: 'synthetic'
# Processing file: ../test/withsynthethic\synthetic_3_hw00001 (2).svc
# Error processing file ../test/withsynthethic\synthetic_3_hw00001 (2).svc: invalid literal for int() with base 10: 'synthetic'
# Processing file: ../test/withsynthethic\synthetic_3_hw00001.svc
# Error processing file ../test/withsynthethic\synthetic_3_hw00001.svc: invalid literal for int() with base 10: 'synthetic'
# Processing file: ../test/withsynthethic\synthetic_3_hw00002 (2).svc
# Error processing file ../test/withsynthethic\synthetic_3_hw00002 (2).svc: invalid literal for int() with base 10: 'synthetic'
# Processing file: ../test/withsynthethic\synthetic_3_hw00002.svc
# Error processing file ../test/withsynthethic\synthetic_3_hw00002.svc: invalid literal for int() with base 10: 'synthetic'
# Processing file: ../test/withsynthethic\synthetic_3_hw00003 (2).svc
# Error processing file ../test/withsynthethic\synthetic_3_hw00003 (2).svc: invalid literal for int() with base 10: 'synthetic'
# Processing file: ../test/withsynthethic\synthetic_3_hw00003.svc
# Error processing file ../test/withsynthethic\synthetic_3_hw00003.svc: invalid literal for int() with base 10: 'synthetic'
# Processing file: ../test/withsynthethic\synthetic_3_hw00004 (2).svc
# Error processing file ../test/withsynthethic\synthetic_3_hw00004 (2).svc: invalid literal for int() with base 10: 'synthetic'
# Processing file: ../test/withsynthethic\synthetic_3_hw00004.svc
# Error processing file ../test/withsynthethic\synthetic_3_hw00004.svc: invalid literal for int() with base 10: 'synthetic'
# Processing file: ../test/withsynthethic\synthetic_3_hw00005 (2).svc
# Error processing file ../test/withsynthethic\synthetic_3_hw00005 (2).svc: invalid literal for int() with base 10: 'synthetic'
# Processing file: ../test/withsynthethic\synthetic_3_hw00005.svc
# Error processing file ../test/withsynthethic\synthetic_3_hw00005.svc: invalid literal for int() with base 10: 'synthetic'
# Processing file: ../test/withsynthethic\synthetic_3_hw00006 (2).svc
# Error processing file ../test/withsynthethic\synthetic_3_hw00006 (2).svc: invalid literal for int() with base 10: 'synthetic'
# Processing file: ../test/withsynthethic\synthetic_3_hw00006.svc
# Error processing file ../test/withsynthethic\synthetic_3_hw00006.svc: invalid literal for int() with base 10: 'synthetic'
# Processing file: ../test/withsynthethic\synthetic_3_hw00007 (2).svc
# Error processing file ../test/withsynthethic\synthetic_3_hw00007 (2).svc: invalid literal for int() with base 10: 'synthetic'
# Processing file: ../test/withsynthethic\synthetic_3_hw00007.svc
# Error processing file ../test/withsynthethic\synthetic_3_hw00007.svc: invalid literal for int() with base 10: 'synthetic'

# %% [markdown]
# ## FEATURE EXTRACTION

# %%
# Cell 3
# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(message)s')
logger = logging.getLogger()

def extract_time_domain_features(data_array):
    """
    Modified to handle 3D data (files x samples x features)
    """
    features_per_file = []
    
    for file_data in data_array:
        means = np.mean(file_data, axis=0)
        stds = np.std(file_data, axis=0)
        mins = np.min(file_data, axis=0)
        maxs = np.max(file_data, axis=0)
        percentile_25 = np.percentile(file_data, 25, axis=0)
        percentile_50 = np.percentile(file_data, 50, axis=0)
        percentile_75 = np.percentile(file_data, 75, axis=0)
        
        file_features = np.concatenate([
            means, stds, mins, maxs,
            percentile_25, percentile_50, percentile_75
        ])
        
        features_per_file.append(file_features)
    
    return np.array(features_per_file)

def extract_frequency_domain_features(data_array):
    """
    Modified to handle 3D data (files x samples x features)
    """
    features_per_file = []
    
    for file_data in data_array:
        freq_features = np.fft.fft(file_data, axis=0)
        freq_magnitude = np.abs(freq_features)
        
        dominant_freqs = np.argmax(freq_magnitude, axis=0)
        freq_energies = np.sum(freq_magnitude, axis=0)
        
        file_features = np.concatenate([dominant_freqs, freq_energies])
        features_per_file.append(file_features)
    
    return np.array(features_per_file)

def extract_statistical_features(data_array):
    """
    Modified to handle 3D data (files x samples x features)
    """
    features_per_file = []
    
    for file_data in data_array:
        means = np.mean(file_data, axis=0)
        medians = np.median(file_data, axis=0)
        variances = np.var(file_data, axis=0)
        skewness = skew(file_data, axis=0)
        kurtosis_vals = kurtosis(file_data, axis=0)
        
        file_features = np.concatenate([
            means, medians, variances, skewness, kurtosis_vals
        ])
        features_per_file.append(file_features)
    
    return np.array(features_per_file)

# Example usage:
def process_features(data):
    """
    Process all features at once and combine them
    """
    time_features = extract_time_domain_features(data)
    freq_features = extract_frequency_domain_features(data)
    stat_features = extract_statistical_features(data)
    
    # Combine all features
    combined_features = np.concatenate([
        time_features,
        freq_features,
        stat_features
    ], axis=1)
    
    return combined_features

# %%
# Cell 4
data, labels = load_emothaw_data(r'../test/label copy/')

# Extract features per file
time_domain_features = extract_time_domain_features(data)
frequency_domain_features = extract_frequency_domain_features(data)
statistical_features = extract_statistical_features(data)

# Combine features
features = np.concatenate((time_domain_features, frequency_domain_features, statistical_features), axis=1)

print("Features shape per component:")
print(f"Time Domain Features: {time_domain_features.shape}")
print(f"Frequency Domain Features: {frequency_domain_features.shape}")
print(f"Statistical Features: {statistical_features.shape}")
print(f"Combined Features: {features.shape}")
# Out:
# Processing file: ../test/label copy\0_hw00001.svc
# Processed file ../test/label copy\0_hw00001.svc: Shape (2643, 7)
# Processing file: ../test/label copy\0_hw00002.svc
# Processed file ../test/label copy\0_hw00002.svc: Shape (5691, 7)
# Processing file: ../test/label copy\0_hw00003.svc
# Processed file ../test/label copy\0_hw00003.svc: Shape (3863, 7)
# Processing file: ../test/label copy\0_hw00004.svc
# Processed file ../test/label copy\0_hw00004.svc: Shape (1178, 7)
# Processing file: ../test/label copy\0_hw00005.svc
# Processed file ../test/label copy\0_hw00005.svc: Shape (770, 7)
# Processing file: ../test/label copy\0_hw00006.svc
# Processed file ../test/label copy\0_hw00006.svc: Shape (4051, 7)
# Processing file: ../test/label copy\0_hw00007.svc
# Processed file ../test/label copy\0_hw00007.svc: Shape (3050, 7)
# Processing file: ../test/label copy\1_hw00001.svc
# Processed file ../test/label copy\1_hw00001.svc: Shape (2560, 7)
# Processing file: ../test/label copy\1_hw00002.svc
# Processed file ../test/label copy\1_hw00002.svc: Shape (3098, 7)
# Processing file: ../test/label copy\1_hw00003.svc
# Processed file ../test/label copy\1_hw00003.svc: Shape (3268, 7)
# Processing file: ../test/label copy\1_hw00004.svc
# Processed file ../test/label copy\1_hw00004.svc: Shape (1452, 7)
# Processing file: ../test/label copy\1_hw00005.svc
# Processed file ../test/label copy\1_hw00005.svc: Shape (786, 7)
# Processing file: ../test/label copy\1_hw00006.svc
# Processed file ../test/label copy\1_hw00006.svc: Shape (1605, 7)
# Processing file: ../test/label copy\1_hw00007.svc
# Processed file ../test/label copy\1_hw00007.svc: Shape (2615, 7)
# Processing file: ../test/label copy\2_hw00001.svc
# Processed file ../test/label copy\2_hw00001.svc: Shape (1474, 7)
# Processing file: ../test/label copy\2_hw00002.svc
# Processed file ../test/label copy\2_hw00002.svc: Shape (2735, 7)
# Processing file: ../test/label copy\2_hw00003.svc
# Processed file ../test/label copy\2_hw00003.svc: Shape (3102, 7)
# Processing file: ../test/label copy\2_hw00004.svc
# Processed file ../test/label copy\2_hw00004.svc: Shape (1951, 7)
# Processing file: ../test/label copy\2_hw00005.svc
# Processed file ../test/label copy\2_hw00005.svc: Shape (1208, 7)
# Processing file: ../test/label copy\2_hw00006.svc
# Processed file ../test/label copy\2_hw00006.svc: Shape (2507, 7)
# Processing file: ../test/label copy\2_hw00007.svc
# Processed file ../test/label copy\2_hw00007.svc: Shape (2985, 7)
# Processing file: ../test/label copy\3_hw00001.svc
# Processed file ../test/label copy\3_hw00001.svc: Shape (2983, 7)
# Processing file: ../test/label copy\3_hw00002.svc
# Processed file ../test/label copy\3_hw00002.svc: Shape (5639, 7)
# Processing file: ../test/label copy\3_hw00003.svc
# Processed file ../test/label copy\3_hw00003.svc: Shape (3857, 7)
# Processing file: ../test/label copy\3_hw00004.svc
# Processed file ../test/label copy\3_hw00004.svc: Shape (1272, 7)
# Processing file: ../test/label copy\3_hw00005.svc
# Processed file ../test/label copy\3_hw00005.svc: Shape (990, 7)
# Processing file: ../test/label copy\3_hw00006.svc
# Processed file ../test/label copy\3_hw00006.svc: Shape (6790, 7)
# Processing file: ../test/label copy\3_hw00007.svc
# Processed file ../test/label copy\3_hw00007.svc: Shape (3661, 7)
# Features shape per component:
# Time Domain Features: (28, 49)
# Frequency Domain Features: (28, 14)
# Statistical Features: (28, 35)
# Combined Features: (28, 98)
# C:\Users\katod\AppData\Local\Temp\ipykernel_17960\3368346268.py:58: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = skew(file_data, axis=0)
# C:\Users\katod\AppData\Local\Temp\ipykernel_17960\3368346268.py:59: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis_vals = kurtosis(file_data, axis=0)

# %%
# Cell 5
class MultiHeadSelfAttention(layers.Layer):
    def __init__(self, embed_dim, num_heads):
        super(MultiHeadSelfAttention, self).__init__()
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        
        if embed_dim % num_heads != 0:
            raise ValueError(f"embedding dimension = {embed_dim} should be divisible by number of heads = {num_heads}")
        
        self.projection_dim = embed_dim // num_heads
        self.query_dense = layers.Dense(embed_dim)
        self.key_dense = layers.Dense(embed_dim)
        self.value_dense = layers.Dense(embed_dim)
        self.combine_heads = layers.Dense(embed_dim)

    def attention(self, query, key, value):
        score = tf.matmul(query, key, transpose_b=True)
        dim_key = tf.cast(tf.shape(key)[-1], tf.float32)
        scaled_score = score / tf.math.sqrt(dim_key)
        
        # Add numerical stability with cliping
        scaled_score = tf.clip_by_value(scaled_score, -5., 5.)
        weights = tf.nn.softmax(scaled_score, axis=-1)
        output = tf.matmul(weights, value)
        return output, weights

    def separate_heads(self, x, batch_size):
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.projection_dim))
        return tf.transpose(x, perm=[0, 2, 1, 3])

    def call(self, inputs):
        batch_size = tf.shape(inputs)[0]
        
        query = self.query_dense(inputs)
        key = self.key_dense(inputs)
        value = self.value_dense(inputs)
        
        query = self.separate_heads(query, batch_size)
        key = self.separate_heads(key, batch_size)
        value = self.separate_heads(value, batch_size)
        
        attention, weights = self.attention(query, key, value)
        attention = tf.transpose(attention, perm=[0, 2, 1, 3])
        concat_attention = tf.reshape(attention, (batch_size, -1, self.embed_dim))
        output = self.combine_heads(concat_attention)
        return output

class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.att = MultiHeadSelfAttention(embed_dim, num_heads)
        self.ffn = tf.keras.Sequential([
            layers.Dense(ff_dim, activation="relu"),
            layers.BatchNormalization(),  # Added BatchNorm
            layers.Dense(embed_dim)
        ])
        
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)

    def call(self, inputs, training):
        attn_output = self.att(inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

# %% [markdown]
# ## Transformer Block

# %% [markdown]
# Transformer Classifier

# %%
# Cell 6

from sklearn.model_selection import train_test_split
import numpy as np
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers, Model

class TransformerClassifier(Model):
    def __init__(self, num_classes, embed_dim, num_heads, ff_dim, num_layers):
        super(TransformerClassifier, self).__init__()
        
        # Add input normalization
        self.input_norm = layers.BatchNormalization()
        self.dense_input = layers.Dense(embed_dim, activation='relu')
        
        self.transformer_blocks = [
            TransformerBlock(embed_dim, num_heads, ff_dim) for _ in range(num_layers)
        ]
        
        self.global_average_pooling = layers.GlobalAveragePooling1D()
        self.dropout = layers.Dropout(0.2)  # Added dropout
        self.dense1 = layers.Dense(32, activation='relu')  # Added intermediate layer
        self.dense2 = layers.Dense(num_classes, activation='softmax')

    def call(self, inputs, training=False):
        x = self.input_norm(inputs, training=training)
        x = self.dense_input(x)
        x = tf.expand_dims(x, axis=1)  # Add sequence dimension
        
        for transformer in self.transformer_blocks:
            x = transformer(x, training=training)
        
        x = self.global_average_pooling(x)
        x = self.dropout(x, training=training)
        x = self.dense1(x)
        return self.dense2(x)

from sklearn.preprocessing import StandardScaler


# Splitting the data into training and testing sets
features = np.concatenate((time_domain_features, frequency_domain_features, statistical_features), axis=1)
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# Defining the model parameters
# Model parameters
num_classes = 4
embed_dim = 128  # Increased embedding dimension
num_heads = 4    # Increased number of heads
ff_dim = 256    # Increased feedforward dimension
num_layers = 2   # Increased number of layers

# Create and compile model with learning rate scheduling
initial_learning_rate = 0.0001
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=100,
    decay_rate=0.9,
    staircase=True
)
# Creating the Transformer model
model = TransformerClassifier(num_classes, embed_dim, num_heads, ff_dim, num_layers)
model.compile(
    optimizer=Adam(learning_rate=lr_schedule, clipnorm=1.0),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=30,
    restore_best_weights=True
)

history = model.fit(
    X_train, y_train,
    epochs=30,
    batch_size=16,
    validation_split=0.2,
    callbacks=[early_stopping],  # Removed reduce_lr
    verbose=1
)

directory = './newmodels/'
model_path = os.path.join(directory, 'emotion_classifier.model.keras')
model.save(model_path)

# Evaluate model
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")

# Modified classify_svc_file function
def classify_svc_file(model, file_path, scaler):
    """
    Classifies a single SVC file with proper scaling
    """
    with open(file_path, 'r') as f:
        lines = [line.strip() for line in f.readlines() if line.strip()]
    
    df = pd.DataFrame([line.split() for line in lines])
    data = df.iloc[1:, :].values
    valid_data = np.array([row for row in data if len(row) == 7], dtype=float)
    valid_data = valid_data.reshape(1, *valid_data.shape)
    
    # Extract features
    time_features = extract_time_domain_features(valid_data)
    freq_features = extract_frequency_domain_features(valid_data)
    stat_features = extract_statistical_features(valid_data)
    
    # Combine features
    combined_features = np.concatenate((time_features, freq_features, stat_features), axis=1)
    
    # Scale features using the same scaler used for training
    scaled_features = scaler.transform(combined_features)
    
    # Get prediction
    prediction = model.predict(scaled_features)
    predicted_class = np.argmax(prediction[0])
    confidence = prediction[0][predicted_class]
    
    emotion_map = {
        0: "Normal",
        1: "Depression",
        2: "Anxiety",
        3: "Stress"
    }
    
    return emotion_map[predicted_class], confidence, prediction[0]
# Out:
# Epoch 1/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.3002 - loss: 1.3863 - val_accuracy: 0.4000 - val_loss: 1.3863
# Epoch 2/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.3002 - loss: 1.3863 - val_accuracy: 0.4000 - val_loss: 1.3863
# Epoch 3/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.3002 - loss: 1.3862 - val_accuracy: 0.4000 - val_loss: 1.3864
# Epoch 4/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 187ms/step - accuracy: 0.2794 - loss: 1.3862 - val_accuracy: 0.4000 - val_loss: 1.3864
# Epoch 5/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.3002 - loss: 1.3862 - val_accuracy: 0.4000 - val_loss: 1.3864
# Epoch 6/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.2794 - loss: 1.3862 - val_accuracy: 0.4000 - val_loss: 1.3865
# Epoch 7/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.3002 - loss: 1.3861 - val_accuracy: 0.4000 - val_loss: 1.3865
# Epoch 8/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.3002 - loss: 1.3861 - val_accuracy: 0.4000 - val_loss: 1.3865
# Epoch 9/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.3002 - loss: 1.3861 - val_accuracy: 0.4000 - val_loss: 1.3866
# Epoch 10/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 339ms/step - accuracy: 0.3002 - loss: 1.3860 - val_accuracy: 0.0000e+00 - val_loss: 1.3866
# Epoch 11/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - accuracy: 0.3002 - loss: 1.3860 - val_accuracy: 0.0000e+00 - val_loss: 1.3867
# Epoch 12/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.3002 - loss: 1.3860 - val_accuracy: 0.0000e+00 - val_loss: 1.3867
# Epoch 13/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.2794 - loss: 1.3860 - val_accuracy: 0.0000e+00 - val_loss: 1.3867
# Epoch 14/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.3002 - loss: 1.3860 - val_accuracy: 0.0000e+00 - val_loss: 1.3868
# Epoch 15/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.3002 - loss: 1.3860 - val_accuracy: 0.0000e+00 - val_loss: 1.3868
# Epoch 16/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - accuracy: 0.2794 - loss: 1.3859 - val_accuracy: 0.0000e+00 - val_loss: 1.3868
# Epoch 17/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.3002 - loss: 1.3859 - val_accuracy: 0.0000e+00 - val_loss: 1.3868
# Epoch 18/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.3002 - loss: 1.3859 - val_accuracy: 0.0000e+00 - val_loss: 1.3869
# Epoch 19/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step - accuracy: 0.3002 - loss: 1.3859 - val_accuracy: 0.0000e+00 - val_loss: 1.3869
# Epoch 20/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - accuracy: 0.3002 - loss: 1.3858 - val_accuracy: 0.0000e+00 - val_loss: 1.3869
# Epoch 21/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.3002 - loss: 1.3858 - val_accuracy: 0.0000e+00 - val_loss: 1.3870
# Epoch 22/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.3002 - loss: 1.3858 - val_accuracy: 0.0000e+00 - val_loss: 1.3870
# Epoch 23/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.2794 - loss: 1.3858 - val_accuracy: 0.0000e+00 - val_loss: 1.3870
# Epoch 24/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.3002 - loss: 1.3857 - val_accuracy: 0.0000e+00 - val_loss: 1.3870
# Epoch 25/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.3002 - loss: 1.3856 - val_accuracy: 0.0000e+00 - val_loss: 1.3871
# Epoch 26/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.3002 - loss: 1.3857 - val_accuracy: 0.0000e+00 - val_loss: 1.3871
# Epoch 27/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 342ms/step - accuracy: 0.3002 - loss: 1.3857 - val_accuracy: 0.0000e+00 - val_loss: 1.3871
# Epoch 28/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.2402 - loss: 1.3857 - val_accuracy: 0.2000 - val_loss: 1.3871
# Epoch 29/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.2794 - loss: 1.3857 - val_accuracy: 0.2000 - val_loss: 1.3872
# Epoch 30/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 182ms/step - accuracy: 0.3002 - loss: 1.3856 - val_accuracy: 0.2000 - val_loss: 1.3872
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.0000e+00 - loss: 1.3864
# Test Loss: 1.386362075805664, Test Accuracy: 0.0

# %%
# Cell 7
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

y_pred = np.argmax(model.predict(X_test), axis=1)

# Compute and display confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
class_labels = ['Normal', 'Depression', 'Anxiety', 'Stress']

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", 
            xticklabels=class_labels, yticklabels=class_labels)
plt.ylabel('Actual Labels')
plt.xlabel('Predicted Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
# Example usage of classify_svc_file
file_path = "./input_files/1_hw00001.svc"
emotion, confidence, probs = classify_svc_file(model, file_path, scaler)
print(f"Predicted emotion: {emotion} (Confidence: {confidence:.2%})")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Predicted emotion: Anxiety (Confidence: 25.07%)

# %%
# Cell 8
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score
from tabulate import tabulate

# Print classification report with improved formatting
print("Classification Report:")
report = classification_report(y_test, y_pred, target_names=class_labels, output_dict=True)

# Convert classification report to a table
headers = ["Class", "Precision", "Recall", "F1-Score", "Support"]
rows = [[cls, 
         f"{metrics['precision']:.2f}", 
         f"{metrics['recall']:.2f}", 
         f"{metrics['f1-score']:.2f}", 
         int(metrics['support'])] for cls, metrics in report.items() if cls != 'accuracy']

# Add accuracy row separately
accuracy_row = ["Accuracy", "-", "-", f"{accuracy_score(y_test, y_pred) * 100:.2f}%", "-"]
rows.append(accuracy_row)

# Print the table
print(tabulate(rows, headers, tablefmt="fancy_grid"))

# Compute and display individual scores
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

# Display overall metrics in a formatted style
print("\nOverall Metrics:")
overall_metrics = [
    ["Metric", "Score"],
    ["Accuracy", f"{accuracy * 100:.2f}%"],
    ["Precision (weighted)", f"{precision:.2f}"],
    ["Recall (weighted)", f"{recall:.2f}"],
    ["F1-Score (weighted)", f"{f1:.2f}"]
]

print(tabulate(overall_metrics, headers="firstrow", tablefmt="fancy_grid"))
# Out:
# Classification Report:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 7
#       5 # Print classification report with improved formatting
#       6 print("Classification Report:")
# ----> 7 report = classification_report(y_test, y_pred, target_names=class_labels, output_dict=True)
#       9 # Convert classification report to a table
#      10 headers = ["Class", "Precision", "Recall", "F1-Score", "Support"]
#
# File c:\Users\katod\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File c:\Users\katod\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:2561, in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2555         warnings.warn(
#    2556             "labels size, {0}, does not match size of target_names, {1}".format(
#    2557                 len(labels), len(target_names)
#    2558             )
#    2559         )
#    2560     else:
# -> 2561         raise ValueError(
#    2562             "Number of classes, {0}, does not match size of "
#    2563             "target_names, {1}. Try specifying the labels "
#    2564             "parameter".format(len(labels), len(target_names))
#    2565         )
#    2566 if target_names is None:
#    2567     target_names = ["%s" % l for l in labels]
#
# ValueError: Number of classes, 3, does not match size of target_names, 4. Try specifying the labels parameter

# %% [markdown]
# # END
